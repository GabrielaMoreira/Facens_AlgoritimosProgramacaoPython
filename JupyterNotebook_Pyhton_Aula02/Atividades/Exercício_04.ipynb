# %% [markdown]
# # Exercício 4
#
# ## Escreva um programa que calcule os valores das tabuadas do 1 ao 10 de forma simultânea (1 thread por tabuada) e imprima na tela a lista com os resultados de cada tabuada
